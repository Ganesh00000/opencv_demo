# %%
import cv2
import numpy
import matplotlib.pyplot as plt

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-d2823d59-d4ff-49cc-84de-afb5d6f47515" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d2823d59-d4ff-49cc-84de-afb5d6f47515">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 159fd33380ec213fc514be7ad7af555d.jpg to 159fd33380ec213fc514be7ad7af555d.jpg
# ...

# %%
img=cv2.imread("/content/159fd33380ec213fc514be7ad7af555d.jpg",1)

# %%
img.shape
# Out:
# (937, 604, 3)

# %%
plt.imshow(img)

# %%
img1=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
img1.shape
# Out:
# (937, 604)

# %%
plt.imshow(img1)

# %%
img2=cv2.cvtColor(img1,cv2.COLOR_GRAY2BGR)

# %%
img2.shape
# Out:
# (937, 604, 3)

# %%
plt.imshow(img2)

# %%
img_res=cv2.resize(img,(1000,1000))

# %%
img_res.shape
# Out:
# (1000, 1000, 3)

# %%
plt.imshow(img_res)

# %%
ret,thres_img=cv2.threshold(img2,127,255,cv2.THRESH_BINARY)
ret,thresh_inv_img=cv2.threshold(img2,127,255,cv2.THRESH_BINARY_INV)
ret,thresh_trunc_img=cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
ret,thresh_tozero_img=cv2.threshold(img,128,255,cv2.THRESH_TOZERO)

# %%
plt.imshow(thres_img)

# %%
plt.imshow(thresh_inv_img)

# %%
plt.imshow(thresh_trunc_img)

# %%
plt.imshow(thresh_tozero_img)

# %%
# !git clone https://github.com/opencv/opencv/tree/master/data/haarcascades
# Out:
# Cloning into 'haarcascades'...
# fatal: repository 'https://github.com/opencv/opencv/tree/master/data/haarcascades/' not found

# %%
face_cascade=cv2.CascadeClassifier(cv2.data.haarcascades+"haarcascade_frontalface_default.xml")

# %%
faces=face_cascade.detectMultiScale(gray,1.1,3)
for x,y,w,h in faces:
  cv2.rectangle(img_,(x,y),(x+w,y+h),(0,0,255),5)
plt.imshow(img_)

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-83433aaa-6252-4fa1-8f27-c74f43917229" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-83433aaa-6252-4fa1-8f27-c74f43917229">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 63063.jpg to 63063.jpg
# ...

# %%
img_=cv2.imread("/content/63063.jpg")

# %%
gray=cv2.cvtColor(img_,cv2.COLOR_BGR2GRAY)
